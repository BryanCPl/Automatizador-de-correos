# %% [markdown]
# <a href="https://colab.research.google.com/github/BryanCPl/Automatizador-de-correos/blob/main/translatorPF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pinyinBPMF={
    "b":"ㄅ",
    "p":"ㄆ",
    "m":"ㄇ",
    "f":"ㄈ",
    "d":"ㄉ",
    "t":"ㄊ",
    "n":"ㄋ",
    "l":"ㄌ",
    "g":"ㄍ",
    "k":"ㄎ",
    "h":"ㄏ",
    "j":"ㄐ",
    "q":"ㄑ",
    "x":"ㄒ",
    "zh":"ㄓ",
    "ch":"ㄔ",
    "sh":"ㄕ",
    "r":"ㄖ",
    "z":"ㄗ",
    "c":"ㄘ",
    "s":"ㄙ",
    "a":"ㄚ",
    "o":"ㄛ",
    "e":"ㄜ",
    "i":"ㄧ",
    "u":"ㄨ",
    "v":"ㄩ" # 'v' is often used for 'ü' in pinyin input methods
}
